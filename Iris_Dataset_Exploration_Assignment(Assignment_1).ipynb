# %% [markdown]
# # Detailed Data Exploration and Preprocessing on the Iris Dataset

# %% [markdown]
# #### Objective:
# To familiarize yourself with the Iris dataset by conducting a thorough data exploration and preprocessing exercise. This assignment will help you develop a deeper understanding of dataset characteristics and the preprocessing steps required before applying machine learning models.
#
# #### Dataset:
# The Iris dataset is a famous dataset that contains 150 samples of iris flowers, each with four features: sepal length, sepal width, petal length, and petal width. It includes three species of iris flowers: setosa, versicolor, and virginica. Your task will be to explore this dataset in detail.

# %% [markdown]
# 1. **Load the Dataset:**
#    - Import necessary libraries (e.g., pandas, matplotlib, seaborn).
#    - Load the Iris dataset using scikit-learn and convert it into a DataFrame.

# %%
# Your code here
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.datasets import load_iris
iris=load_iris()

# %%
df=pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df['target']=iris.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %% [markdown]
# Your explanation here

# %% [markdown]
# 2. **Basic Dataset Analysis:**
#    - Print the shape of the dataset to understand its size.
#    - List all feature names and the target variable.

# %%
# Your code here

df.columns[:-1]
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
df.columns[-1]
# Out:
# 'target'

# %% [markdown]
# Your explanation here

# %% [markdown]
# 3. **Display Data:**
#    - Display the first five rows of the dataset to get a preliminary view of the data.

# %%
# Your code here
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# Your explanation here

# %% [markdown]
# 4. **Check for Missing Values:**
#    - Check the dataset for any missing values.
#    - Report the number of missing values found in each column.

# %%
# Your code here
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %% [markdown]
# Your explanation here

# %% [markdown]
# 5. **Handle Missing Values (If Any):**
#    - If missing values are found, discuss and apply a strategy to handle them (e.g., removing the rows, replacing with mean/median).

# %%
# Your code here

df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %% [markdown]
# Your explanation here

# %% [markdown]
# 6. **Data Type Analysis:**
#    - Print the data type of each column.
#    - Ensure that all feature columns are of numeric type and the target variable is categorical.

# %%
# Your code here
df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int32
# dtype: object

# %%
df['target']=df['target'].astype(object)

# %%
df.sample()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 128                6.4               2.8                5.6               2.1
#
#     target
# 128      2

# %%
df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                object
# dtype: object

# %% [markdown]
# Your explanation here

# %% [markdown]
# 7. **Statistical Summary:**
#    - Display a statistical summary of the feature variables (mean, median, min, max, std).

# %%
# Your code here
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# Your explanation here

# %% [markdown]
# 8. **Distribution Analysis:**
#    - Visualize the distribution of each feature using histograms. Consider using separate histograms or a single figure with subplots for each feature.

# %%
# Your code here
df.hist()
# Out:
# array([[<Axes: title={'center': 'sepal length (cm)'}>,
#         <Axes: title={'center': 'sepal width (cm)'}>],
#        [<Axes: title={'center': 'petal length (cm)'}>,
#         <Axes: title={'center': 'petal width (cm)'}>]], dtype=object)

# %% [markdown]
# Your explanation here

# %% [markdown]
# 9. **Feature Relationships:**
#    - Use scatter plots to analyze the relationships between each pair of features. Color the points by the target variable to see if there's any noticeable pattern or separation between the species.

# %%
# Your code here
import seaborn as sns
sns.pairplot(df,hue="target",palette='muted')

# %% [markdown]
# Your explanation here

# %% [markdown]
# 10. **Correlation Analysis:**
#     - Calculate and visualize the correlation matrix for the features to understand how the features are related to each other.

# %%
# Your code here
df.corr()
# Out:
# C:\Users\assis\AppData\Local\Temp\ipykernel_40328\3840887929.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %% [markdown]
# Your explanation here

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\assis\AppData\Local\Temp\ipykernel_40328\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >
